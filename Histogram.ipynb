# %% [markdown]
# <a href="https://colab.research.google.com/github/Rijalpratama23/PengolahanCitraDigital/blob/main/Histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

image = cv2.imread ('formal.jpg')
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=913x1280>
# -1

# %%
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.title('RGB COLOR')
plt.imshow(img_rgb)

# %%
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)

plt.title('GRAY COLOR')
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# MEMBUAT HISTOGRAM DARI CITRA GRAYSCALE

# %%
# Hitung histogram gambar grayscale
hist = cv2.calcHist([img_gray], [0], None, [256], [0,256])

# Plot histogram
plt.plot(hist, color='black')
plt.title("Histogram Grayscale")
plt.xlabel("Intensitas (0 - 255)")
plt.ylabel("Jumlah Piksel")
plt.show()

# %% [markdown]
# MEMBUAT HISTOGRAM CITRA RGB

# %%
# Hitung histogram untuk channel Red (index 2)
hist_red = cv2.calcHist([img_rgb], [2], None, [256], [0,256])

# Plot histogram Red
plt.plot(hist_red, color='r')
plt.title("Histogram Red Channel")
plt.xlabel("Intensitas (0-255)")
plt.ylabel("Jumlah Piksel")
plt.show()

# %%
# Hitung histogram untuk channel green (index 1)
hist_green = cv2.calcHist([img_rgb], [1], None, [256], [0,256])

# Plot histogram Red
plt.plot(hist_green, color='g')
plt.title("Histogram Green Channel")
plt.xlabel("Intensitas (0-255)")
plt.ylabel("Jumlah Piksel")
plt.show()

# %%
# Hitung histogram untuk channel green (index 0)
hist_blue = cv2.calcHist([img_rgb], [0], None, [256], [0,256])

# Plot histogram Red
plt.plot(hist_blue, color='b')
plt.title("Histogram Blue Channel")
plt.xlabel("Intensitas (0-255)")
plt.ylabel("Jumlah Piksel")
plt.show()

# %% [markdown]
# HISTOGRAM GABUNGAN

# %%
# Warna channel
color = ('b', 'g', 'r')

plt.figure(figsize=(8,6))
for i, col in enumerate(color):
    hist = cv2.calcHist([img_rgb], [i], None, [256], [0,256])
    plt.plot(hist, color=col, label=col.upper())
    plt.xlim([0,256])

plt.title("Histogram Gabungan RGB")
plt.xlabel("Intensitas (0-255)")
plt.ylabel("Jumlah Piksel")
plt.legend()
plt.show()

# %%
# Tambah kecerahan (misal +100)
img_bright = cv2.convertScaleAbs(image, alpha=1, beta=100)

# Tampilkan sebelum & sesudah
plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Asli")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(img_bright, cv2.COLOR_BGR2RGB))
plt.title("Lebih Cerah (+100)")
plt.axis("off")

plt.show()

# %%
plt.subplot(2,2,4)
for i, col in enumerate(['b','g','r']):
    hist = cv2.calcHist([img_bright],[i],None,[256],[0,256])
    plt.plot(hist, color=col)
plt.title("Histogram Setelah Diberi Kecerahan")

plt.tight_layout()
plt.show()
